# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

import sempy.fabric as fabric
import pandas as pd
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 4, Finished, Available, Finished)

# %%
fabric.list_datasets()
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 5, Finished, Available, Finished)
#   Dataset Name                            Dataset ID   Created Timestamp  \
# 0      sm-demo  d8cc4786-df93-4f02-b947-bc0bd8fec278 2024-08-24 18:52:26
# 1   demoday_LH  df9f017a-d321-4671-8530-332cb51786b1 2021-02-12 23:00:58
# 2    dd_silver  f3ad5dae-52cc-43f2-879d-f75ddf9c0ef1 2021-02-12 23:00:58
#
#   Last Update
# 0         NaT
# 1         NaT
# 2         NaT

# %%
ds = 'sm-demo'
ws = 'demo-day'
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 6, Finished, Available, Finished)

# %%
fabric.list_tables(ds)
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 7, Finished, Available, Finished)
#               Name Description  Hidden Data Category              Type
# 0          DimDate               False                           Table
# 1      DimCustomer               False                           Table
# 2       DimProduct               False                           Table
# 3   FactSalesOrder               False                           Table
# 4      Items Count               False                Calculated Table
# 5  SalesByCategory               False                Calculated Table
# 6        _measures               False                           Table
# 7          mytable               False                           Table

# %%
fabric.list_measures(ds)
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 8, Finished, Available, Finished)
#   Table Name            Measure Name                     Measure Expression  \
# 0  _measures       ProductsCatalogue  DISTINCTCOUNT(DimProduct[ProductKey])
# 1  _measures  Total Quantity Ordered          SUM(FactSalesOrder[Quantity])
# 2  _measures             Total Sales        SUM(FactSalesOrder[SalesTotal])
#
#   Measure Data Type  Measure Hidden Measure Display Folder  \
# 0             Int64           False
# 1             Int64           False
# 2            Double           False
#
#   Measure Description Format String Data Category Detail Rows Definition  \
# 0                                 0                                 None
# 1                                 0                                 None
# 2                                                                   None
#
#   Format String Definition
# 0                     None
# 1                     None
# ...

# %%
df = fabric.read_table(ds, 'FactSalesOrder', mode='OneLake')
df.head()
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 11, Finished, Available, Finished)
#    SalesOrderKey  SalesOrderDateKey  ProductKey  CustomerKey  Quantity  \
# 0           1237           20210102         831          281        10
# 1           1258           20210105         711        29489        10
# 2           1260           20210106         780          625        10
# 3           1267           20210107         815        30107        10
# 4           1287           20210110         973          696        10
#
#    SalesTotal
# 0      3488.0
# 1       350.0
# 2     23200.0
# 3       607.0
# 4     17010.0

# %%
df.to_lakehouse_table(
    name='sales',
    mode='overwrite'
)
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 12, Finished, Available, Finished)

# %%
myitems = fabric.read_table(ds, 'mytable', mode='OneLake')
myitems
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 19, Finished, Available, Finished)
#   myitems
# 0  item 1
# 1  item 2
# 2  item 3
# 3       🐈
# 4      🐕🐕

# %%
myitems.to_lakehouse_table('myitems', mode='overwrite')
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 20, Finished, Available, Finished)

# %%
# %%sql
#
# DESCRIBE history myitems
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 21, Finished, Available, Finished)
# <Spark SQL result set with 2 rows and 15 fields>

# %%
delta_table_path = 'Tables/myitems'
# Get the current data
current_data = spark.read.format("delta").load(delta_table_path)
display(current_data)

# Get the version 0 data
original_data = spark.read.format("delta").option("versionAsOf", 0).load(delta_table_path)
display(original_data)
# Out:
# StatementMeta(, ed3215da-024a-45be-9320-94951d6b072f, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 937ca787-9f5d-4941-8f62-08bf0ca16702)
# SynapseWidget(Synapse.DataFrame, f2f0c52e-5f5f-4eec-a37e-43cbd448d543)
